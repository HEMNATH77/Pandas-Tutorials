# %%
import pandas as pd

# %%
#To Read CSV files

df=pd.read_csv("Data Model - Pizza Sales.csv")
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
#To know shape of the data( Rows,Columns)
df.shape
# Out:
# (48620, 12)

# %%
#To See a specific No.of.Columns(here 10 is no.of.columns you want to display)
pd.set_option("display.max_columns",10)
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  ...  \
# 0                     1         1     hawaiian_m         1    1/1/2015  ...
# 1                     2         2  classic_dlx_m         1    1/1/2015  ...
# 2                     3         2  five_cheese_l         1    1/1/2015  ...
# 3                     4         2    ital_supr_l         1    1/1/2015  ...
# 4                     5         2     mexicana_m         1    1/1/2015  ...
# ...                 ...       ...            ...       ...         ...  ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015  ...
# 48616             48617     21348  four_cheese_l         1  12/31/2015  ...
# 48617             48618     21348   napolitana_s         1  12/31/2015  ...
# 48618             48619     21349     mexicana_l         1  12/31/2015  ...
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015  ...
#
#       total_price  pizza_size  pizza_category  \
# ...

# %%
#To View the top columns
df.head(7)
# Out:
#    order_details_id  order_id       pizza_id  quantity order_date  ...  \
# 0                 1         1     hawaiian_m         1   1/1/2015  ...
# 1                 2         2  classic_dlx_m         1   1/1/2015  ...
# 2                 3         2  five_cheese_l         1   1/1/2015  ...
# 3                 4         2    ital_supr_l         1   1/1/2015  ...
# 4                 5         2     mexicana_m         1   1/1/2015  ...
# 5                 6         2     thai_ckn_l         1   1/1/2015  ...
# 6                 7         3    ital_supr_m         1   1/1/2015  ...
#
#   total_price  pizza_size  pizza_category  \
# 0       13.25           M         Classic
# 1       16.00           M         Classic
# 2       18.50           L          Veggie
# 3       20.75           L         Supreme
# 4       16.00           M          Veggie
# 5       20.75           L         Chicken
# 6       16.50           M         Supreme
#
# ...

# %%
#To view bottom columns
df.tail(5)
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  ...  \
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015  ...
# 48616             48617     21348  four_cheese_l         1  12/31/2015  ...
# 48617             48618     21348   napolitana_s         1  12/31/2015  ...
# 48618             48619     21349     mexicana_l         1  12/31/2015  ...
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015  ...
#
#       total_price  pizza_size  pizza_category  \
# 48615       16.75           M         Chicken
# 48616       17.95           L          Veggie
# 48617       12.00           S         Classic
# 48618       20.25           L          Veggie
# 48619       12.75           S         Chicken
#
#                                        pizza_ingredients  \
# 48615  Chicken, Red Onions, Red Peppers, Mushrooms, A...
# 48616  Ricotta Cheese, Gorgonzola Piccante Cheese, Mo...
# ...

# %%
#To grab a specific Column
df['pizza_name']
# Out:
# 0                The Hawaiian Pizza
# 1          The Classic Deluxe Pizza
# 2             The Five Cheese Pizza
# 3         The Italian Supreme Pizza
# 4                The Mexicana Pizza
#                     ...
# 48615     The Chicken Alfredo Pizza
# 48616         The Four Cheese Pizza
# 48617          The Napolitana Pizza
# 48618            The Mexicana Pizza
# 48619    The Barbecue Chicken Pizza
# Name: pizza_name, Length: 48620, dtype: object

# %%
#To grab rows[row_index,'column_name']

df.loc[1,'pizza_name']
# Out:
# 'The Classic Deluxe Pizza'

# %%
#Slicing


#Type1
#df.loc[start:endindex,'column_name']
df.loc[1:5,'pizza_name']
# Out:
# 1     The Classic Deluxe Pizza
# 2        The Five Cheese Pizza
# 3    The Italian Supreme Pizza
# 4           The Mexicana Pizza
# 5       The Thai Chicken Pizza
# Name: pizza_name, dtype: object

# %%
#Type2 
#df.loc[start:endindex,'column_name':'end_column_name']

df.loc[1:3,'pizza_category':'pizza_name']
# Out:
#   pizza_category                                  pizza_ingredients  \
# 1        Classic  Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# 2         Veggie  Mozzarella Cheese, Provolone Cheese, Smoked Go...
# 3        Supreme  Calabrese Salami, Capocollo, Tomatoes, Red Oni...
#
#                   pizza_name
# 1   The Classic Deluxe Pizza
# 2      The Five Cheese Pizza
# 3  The Italian Supreme Pizza

# %%
#Indexes

# %%
df.set_index
# Out:
# <bound method DataFrame.set_index of        order_details_id  order_id       pizza_id  quantity  order_date  ...  \
# 0                     1         1     hawaiian_m         1    1/1/2015  ...
# 1                     2         2  classic_dlx_m         1    1/1/2015  ...
# 2                     3         2  five_cheese_l         1    1/1/2015  ...
# 3                     4         2    ital_supr_l         1    1/1/2015  ...
# 4                     5         2     mexicana_m         1    1/1/2015  ...
# ...                 ...       ...            ...       ...         ...  ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015  ...
# 48616             48617     21348  four_cheese_l         1  12/31/2015  ...
# 48617             48618     21348   napolitana_s         1  12/31/2015  ...
# 48618             48619     21349     mexicana_l         1  12/31/2015  ...
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015  ...
#
# ...

# %%
pd.set_option("display.max_columns",10)
pd.set_option("display.max_rows",5)
df.head(7)
# Out:
#     order_details_id  order_id       pizza_id  quantity order_date  ...  \
# 0                  1         1     hawaiian_m         1   1/1/2015  ...
# 1                  2         2  classic_dlx_m         1   1/1/2015  ...
# ..               ...       ...            ...       ...        ...  ...
# 5                  6         2     thai_ckn_l         1   1/1/2015  ...
# 6                  7         3    ital_supr_m         1   1/1/2015  ...
#
#    total_price  pizza_size  pizza_category  \
# 0        13.25           M         Classic
# 1        16.00           M         Classic
# ..         ...         ...             ...
# 5        20.75           L         Chicken
# 6        16.50           M         Supreme
#
#                                     pizza_ingredients  \
# 0            Sliced Ham, Pineapple, Mozzarella Cheese
# 1   Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ..                                                ...
# ...

# %%
#Cleaning

# %%
schema_df=pd.read_csv("Data Model - Pizza Sales.csv")
pd.set_option("display.max_columns",10)
pd.set_option("display.max_rows",5)
schema_df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  ...  \
# 0                     1         1     hawaiian_m         1    1/1/2015  ...
# 1                     2         2  classic_dlx_m         1    1/1/2015  ...
# ...                 ...       ...            ...       ...         ...  ...
# 48618             48619     21349     mexicana_l         1  12/31/2015  ...
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015  ...
#
#       total_price  pizza_size  pizza_category  \
# 0           13.25           M         Classic
# 1           16.00           M         Classic
# ...           ...         ...             ...
# 48618       20.25           L          Veggie
# 48619       12.75           S         Chicken
#
#                                        pizza_ingredients  \
# 0               Sliced Ham, Pineapple, Mozzarella Cheese
# 1      Pepperoni, Mushrooms, Red Onions, Red Peppers,...
# ...

# %%
#Filters


a=(df["quantity"]>1)
df.loc[a]
# Out:
#        order_details_id  order_id        pizza_id  quantity  order_date  ...  \
# 48                   49        17  mediterraneo_m         2    1/1/2015  ...
# 183                 184        78    spicy_ital_l         3    1/2/2015  ...
# ...                 ...       ...             ...       ...         ...  ...
# 48575             48576     21331       bbq_ckn_l         2  12/31/2015  ...
# 48601             48602     21343    spicy_ital_l         2  12/31/2015  ...
#
#       total_price  pizza_size  pizza_category  \
# 48          32.00           M          Veggie
# 183         62.25           L         Supreme
# ...           ...         ...             ...
# 48575       41.50           L         Chicken
# 48601       41.50           L         Supreme
#
#                                        pizza_ingredients  \
# 48     Spinach, Artichokes, Kalamata Olives, Sun-drie...
# 183    Capocollo, Tomatoes, Goat Cheese, Artichokes, ...
# ...

# %%
#To have a specified column to be filtereda=(df["quantity"]>1)
a=(df["quantity"]>1)
df.loc[a,["quantity","pizza_size"]]
# Out:
#        quantity pizza_size
# 48            2          M
# 183           3          L
# ...         ...        ...
# 48575         2          L
# 48601         2          L
#
# [927 rows x 2 columns]

# %%
#isin
a=([17,78])
filt=df["order_id"].isin(a)
df.loc[filt,"order_id"]
# Out:
# 42     17
# 43     17
#        ..
# 183    78
# 184    78
# Name: order_id, Length: 16, dtype: int64

# %%
#To filter the columns with particular name
filt=df['pizza_name'
df.loc[filt,'pizza_name']
# Out:
#   Cell In[63], line 3
#     df.loc[filt,'pizza_name'=The Mediterranean Pizza]
#                 ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
