# %%
import pandas as pd

# %%
df=pd.read_csv("Data Model - Pizza Sales.csv")
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
#Apply

df['pizza_name'].apply(len)
# Out:
# 0        18
# 1        24
# 2        21
# 3        25
# 4        18
#          ..
# 48615    25
# 48616    21
# 48617    20
# 48618    18
# 48619    26
# Name: pizza_name, Length: 48620, dtype: int64

# %%
#BY USING FUNCTIONS

def update_column_name(pizza_name):
  return pizza_name.upper()

# %%
df['pizza_name'].apply(update_column_name)
# Out:
# 0                THE HAWAIIAN PIZZA
# 1          THE CLASSIC DELUXE PIZZA
# 2             THE FIVE CHEESE PIZZA
# 3         THE ITALIAN SUPREME PIZZA
# 4                THE MEXICANA PIZZA
#                     ...
# 48615     THE CHICKEN ALFREDO PIZZA
# 48616         THE FOUR CHEESE PIZZA
# 48617          THE NAPOLITANA PIZZA
# 48618            THE MEXICANA PIZZA
# 48619    THE BARBECUE CHICKEN PIZZA
# Name: pizza_name, Length: 48620, dtype: object

# %%
df['pizza_name']=df['pizza_name'].apply(update_column_name)
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
df.apply(len)
# Out:
# order_details_id     48620
# order_id             48620
# pizza_id             48620
# quantity             48620
# order_date           48620
# order_time           48620
# unit_price           48620
# total_price          48620
# pizza_size           48620
# pizza_category       48620
# pizza_ingredients    48620
# pizza_name           48620
# dtype: int64

# %%
df.apply(len,axis='columns')
# Out:
# 0        12
# 1        12
# 2        12
# 3        12
# 4        12
#          ..
# 48615    12
# 48616    12
# 48617    12
# 48618    12
# 48619    12
# Length: 48620, dtype: int64

# %%
#Replace
df.rename(columns={'pizza_name':'Special_Pizza'},inplace=True)
df['Special_Pizza']
# Out:
# 0                The Hawaiian Pizza
# 1          The Classic Deluxe Pizza
# 2             The Five Cheese Pizza
# 3         The Italian Supreme Pizza
# 4                The Mexicana Pizza
#                     ...
# 48615     The Chicken Alfredo Pizza
# 48616         The Four Cheese Pizza
# 48617          The Napolitana Pizza
# 48618            The Mexicana Pizza
# 48619    The Barbecue Chicken Pizza
# Name: Special_Pizza, Length: 48620, dtype: object

# %%
#Add and Remove columns
df=pd.read_csv("Data Model - Pizza Sales.csv")
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
#ADD

df['full']=df['pizza_ingredients']+ '  ' +df['pizza_name']
df
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
#REMOVE 
df.drop(columns=['pizza_name'])
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 4                     5         2     mexicana_m         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...

# %%
#Droping by index value

# %%
df.drop(index=4)
# Out:
#        order_details_id  order_id       pizza_id  quantity  order_date  \
# 0                     1         1     hawaiian_m         1    1/1/2015
# 1                     2         2  classic_dlx_m         1    1/1/2015
# 2                     3         2  five_cheese_l         1    1/1/2015
# 3                     4         2    ital_supr_l         1    1/1/2015
# 5                     6         2     thai_ckn_l         1    1/1/2015
# ...                 ...       ...            ...       ...         ...
# 48615             48616     21348  ckn_alfredo_m         1  12/31/2015
# 48616             48617     21348  four_cheese_l         1  12/31/2015
# 48617             48618     21348   napolitana_s         1  12/31/2015
# 48618             48619     21349     mexicana_l         1  12/31/2015
# 48619             48620     21350      bbq_ckn_s         1  12/31/2015
#
#       order_time  unit_price  total_price pizza_size pizza_category  \
# ...
