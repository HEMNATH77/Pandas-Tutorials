# %%
import pandas as pd

# %%
#Creating a Data Frame

a={ "Name":["john","motu","patlu","jatka","none", "chingum","na"],
    "dept":["MECH","CIVIL","CSE","ECE","none","nan","BIOTECH"],
    "id":["001","002","057","175","Missing","003","077"],
    "age":['34','35','36','45','34','Missing',"nan"]}

# %%
df=pd.DataFrame(a)
df
# Out:
#       Name     dept       id      age
# 0     john     MECH      001       34
# 1     motu    CIVIL      002       35
# 2    patlu      CSE      057       36
# 3    jatka      ECE      175       45
# 4     none     none  Missing       34
# 5  chingum      nan      003  Missing
# 6       na  BIOTECH      077      nan

# %%
df.dropna()
# Out:
#       Name     dept       id      age
# 0     john     MECH      001       34
# 1     motu    CIVIL      002       35
# 2    patlu      CSE      057       36
# 3    jatka      ECE      175       45
# 4     none     none  Missing       34
# 5  chingum      nan      003  Missing
# 6       na  BIOTECH      077      nan

# %%
df.dropna(axis=1,how='any')
# Out:
#       Name     dept       id      age
# 0     john     MECH      001       34
# 1     motu    CIVIL      002       35
# 2    patlu      CSE      057       36
# 3    jatka      ECE      175       45
# 4     none     none  Missing       34
# 5  chingum      nan      003  Missing
# 6       na  BIOTECH      077      nan

# %%
a={ "Name":["john","motu","patlu","jatka","none", "chingum","na"],
    "dept":["MECH","CIVIL","CSE","ECE","none","nan","BIOTECH"],
    "id":["001","002","057","175","Missing","003","077"],
    "age":['34','35','36','45','34','Missing',"nan"]}

# %%
#For Csv Files (important)

import pandas as pd

# %%
na_vals=['Na','Missing']
df=pd.read_csv("Data Model - Pizza Sales.csv",index_col='order_details_id',na_values=na_vals)
pd.set_option("display.max_columns",13)
pd.set_option("display.max_rows",10)
df
# Out:
#                   order_id       pizza_id  quantity  order_date order_time  \
# order_details_id
# 1                        1     hawaiian_m         1    1/1/2015   11:38:36
# 2                        2  classic_dlx_m         1    1/1/2015   11:57:40
# 3                        2  five_cheese_l         1    1/1/2015   11:57:40
# 4                        2    ital_supr_l         1    1/1/2015   11:57:40
# 5                        2     mexicana_m         1    1/1/2015   11:57:40
# ...                    ...            ...       ...         ...        ...
# 48616                21348  ckn_alfredo_m         1  12/31/2015   21:23:10
# 48617                21348  four_cheese_l         1  12/31/2015   21:23:10
# 48618                21348   napolitana_s         1  12/31/2015   21:23:10
# 48619                21349     mexicana_l         1  12/31/2015   22:09:54
# 48620                21350      bbq_ckn_s         1  12/31/2015   23:02:05
#
# ...

# %%
df['unit_price'].unique()
# Out:
# array([13.25, 16.  , 18.5 , 20.75, 16.5 , 12.75, 12.  , 12.5 , 20.5 ,
#        20.25, 16.75, 15.25, 17.95, 16.25, 14.75,  9.75, 17.5 , 10.5 ,
#        25.5 , 11.  , 14.5 , 12.25, 21.  , 23.65, 35.95])

# %%
#Converting the values into float 
df['unit_price']=df['unit_price'].astype(float)

# %%
df['unit_price'].mean()
# Out:
# 16.494132044426163

# %%
df['unit_price'].median()
# Out:
# 16.5
